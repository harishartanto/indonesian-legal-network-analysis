# %%
import os
import tiktoken
import pandas as pd
from dotenv import load_dotenv
from openai import AzureOpenAI

# %%
# Load environment variables
load_dotenv(dotenv_path="config/environment_variables.env")

client = AzureOpenAI(
  azure_endpoint=os.environ.get("AZURE_OPENAI_ENDPOINT_TEXT"),
  api_key=os.environ.get("AZURE_OPENAI_KEY_TEXT"),
  api_version=os.environ.get("AZURE_OPENAI_API_VERSION")
)

# %%
generation_prompt = "../../data/prompt/generation.txt"
model = 'gpt-35-turbo-16k'

# get generation prompt text
with open(generation_prompt, "r") as file:
    generation_prompt = file.read()
    
generation_prompt
# Out:
# 'Anda akan menerima konsideran dari peraturan perundang-undangan (PUU) yang berjudul "{doc_title}". Tugas anda adalah mengusulkan topik-topik umum dari konsideran PUU yang diberikan.\n\n[Instruksi]\nUsulkan topik-topik yang dibahas dalam konsideran PUU yang diberikan.\n1. Label topik yang diusulkan harus dapat digeneralisasikan seluas mungkin sehingga tidak boleh terlalu spesifik dan terfokus pada informasi (judul & konsideran) PUU yang diberikan.\n2. Label topik yang diusulkan harus berupa kata benda yang mewakili subjek tunggal saja.\n3. Berikan respon dalam format "Label 1; Label 2; Label 3; dst.".\n\n[Konsideran]\nMenimbang: {doc_consideration}\n\nMohon hanya berikan label topik yang diusulkan dalam respon Anda.\n[Respon Anda]'

# %%
def api_call(model, prompt, max_tokens, temperature, top_p,):
    response = client.chat.completions.create(
            model=model,
            temperature=float(temperature),
            max_tokens=int(max_tokens),
            top_p=float(top_p),
            messages=[
                {"role": "system", "content": "You are a helpful assistant."},
                {"role": "user", "content": prompt},
            ],
        )
    return response.choices[0].message.content


def count_token(messages, model="gpt-35-turbo-16k"):
    if model.startswith("gpt"):
        try:
            encoding = tiktoken.encoding_for_model(model)
        except KeyError:
            encoding = tiktoken.get_encoding("cl100k_base")

        num_tokens = 0
        num_tokens += len(encoding.encode(messages))
        num_tokens += 3  # every reply is primed with <|start|>assistant<|message|>
        return num_tokens
    else:  # Open-source models
        return len(tiktoken.get_encoding("cl100k_base").encode(messages))

# %%
docs_df = pd.read_csv("../../data/law_analyzer_new99_keywords.csv")
docs_df
# Out:
#                  nama_file      nomor_peraturan  \
# 0     01~pmk.010~2011.json  PMK 01/PMK.010/2011
# 1      02~pmk.05~2011.json   PMK 02/PMK.05/2011
# 2      02~pmk.07~2012.json   PMK 02/PMK.07/2012
# 3     03~pmk.011~2012.json  PMK 03/PMK.011/2012
# 4      04~pmk.02~2014.json   PMK 04/PMK.02/2014
# ...                    ...                  ...
# 1631  uu-9-tahun-1992.json      UU 9 TAHUN 1992
# 1632  uu-9-tahun-1995.json      UU 9 TAHUN 1995
# 1633  uu-9-tahun-2009.json      UU 9 TAHUN 2009
# 1634  uu-9-tahun-2015.json      UU 9 TAHUN 2015
# 1635   uu-9tahun-2005.json      UU 9 TAHUN 2005
#
#                                                   judul  tahun  nomor  \
# 0     Perubahan atas Peraturan Menteri Keuangan Nomo...   2011      1
# 1     Pedoman Akuntansi Dan Pelaporan Aset Berupa Ba...   2011      2
# 2     Perkiraan Alokasi Dana Bagi Hasil Sumber Daya ...   2012      2
# 3     Tata Cara Pengelolaan Dan Pertanggungjawaban F...   2012      3
# 4     Perubahan Kedua atas Peraturan Menteri Keuanga...   2014      4
# ...                                                 ...    ...    ...
# 1631                                       Keimigrasian   1992      9
# 1632                                        Usaha Kecil   1995      9
# 1633                             Badan Hukum Pendidikan   2009      9
# 1634  Perubahan Kedua atas Undang-Undang Nomor 23 Ta...   2015      9
# 1635  Perubahan Kedua atas Undang-Undang Nomor 36 Ta...   2005      9
#
#                                              konsideran  \
# 0      a. bahwa dalam rangka memperoleh perhitungan ...
# 1      a. bahwa berdasarkan Peraturan Menteri Keuang...
# 2      bahwa untuk melaksanakan ketentuan Pasal 27 a...
# 3      a. bahwa dalam rangka mendukung usaha pemanfa...
# 4      a. bahwa dalam rangka mendukung agar kondisi ...
# ...                                                 ...
# 1631   a. bahwa pengaturan keimigrasian yang meliput...
# 1632   a. bahwa negara Republik Indonesia yang berda...
# 1633   a. bahwa untuk mewujudkan fungsi dan tujuan p...
# 1634   a. bahwa untuk kesinambungan kepemimpinan di ...
# 1635   a. bahwa Anggaran Pendapatan dan Belanja Nega...
#
#                                                 heading  \
# 0                                                    []
# 1     ['Pengertian', 'Ruang Lingkup', 'Sistem Akunta...
# 2                                                    []
# 3     ['Tujuan', 'Prinsip', 'Bentuk', 'Ruang Lingkup...
# 4                                                    []
# ...                                                 ...
# 1631                                                 []
# 1632                                                 []
# 1633                                                 []
# 1634                                                 []
# 1635                                                 []
#
#                                         definition_term
# 0                                                   NaN
# 1     ['Kontraktor Kontrak Kerja Sama,', 'Barang yan...
# 2     ['Alokasi Dana Bagi Hasil Sumber Daya Alam Keh...
# 3     ['Badan Usaha Penyedia Jasa Penyiapan Proyek K...
# 4                                                   NaN
# ...                                                 ...
# 1631  ['Keimigrasian', 'Wilayah Negara Republik Indo...
# 1632  ['Usaha Kecil', 'Usaha Menengah dan Usaha Besa...
# 1633  ['Badan hukum pendidikan', 'Badan Hukum Pendid...
# 1634                                                NaN
# 1635                                                NaN
#
# [1636 rows x 8 columns]

# %%
# drop rows with missing values in konsideran
#docs_df = docs_df.dropna(subset=["konsideran"])

# %%
# count token for each konsideran
docs_df["token_count"] = docs_df["konsideran"].apply(count_token)
docs_df
# Out:
#                  nama_file      nomor_peraturan  \
# 0     01~pmk.010~2011.json  PMK 01/PMK.010/2011
# 1      02~pmk.05~2011.json   PMK 02/PMK.05/2011
# 2      02~pmk.07~2012.json   PMK 02/PMK.07/2012
# 3     03~pmk.011~2012.json  PMK 03/PMK.011/2012
# 4      04~pmk.02~2014.json   PMK 04/PMK.02/2014
# ...                    ...                  ...
# 1631  uu-9-tahun-1992.json      UU 9 TAHUN 1992
# 1632  uu-9-tahun-1995.json      UU 9 TAHUN 1995
# 1633  uu-9-tahun-2009.json      UU 9 TAHUN 2009
# 1634  uu-9-tahun-2015.json      UU 9 TAHUN 2015
# 1635   uu-9tahun-2005.json      UU 9 TAHUN 2005
#
#                                                   judul  tahun  nomor  \
# 0     Perubahan atas Peraturan Menteri Keuangan Nomo...   2011      1
# 1     Pedoman Akuntansi Dan Pelaporan Aset Berupa Ba...   2011      2
# 2     Perkiraan Alokasi Dana Bagi Hasil Sumber Daya ...   2012      2
# 3     Tata Cara Pengelolaan Dan Pertanggungjawaban F...   2012      3
# 4     Perubahan Kedua atas Peraturan Menteri Keuanga...   2014      4
# ...                                                 ...    ...    ...
# 1631                                       Keimigrasian   1992      9
# 1632                                        Usaha Kecil   1995      9
# 1633                             Badan Hukum Pendidikan   2009      9
# 1634  Perubahan Kedua atas Undang-Undang Nomor 23 Ta...   2015      9
# 1635  Perubahan Kedua atas Undang-Undang Nomor 36 Ta...   2005      9
#
#                                              konsideran  \
# 0      a. bahwa dalam rangka memperoleh perhitungan ...
# 1      a. bahwa berdasarkan Peraturan Menteri Keuang...
# 2      bahwa untuk melaksanakan ketentuan Pasal 27 a...
# 3      a. bahwa dalam rangka mendukung usaha pemanfa...
# 4      a. bahwa dalam rangka mendukung agar kondisi ...
# ...                                                 ...
# 1631   a. bahwa pengaturan keimigrasian yang meliput...
# 1632   a. bahwa negara Republik Indonesia yang berda...
# 1633   a. bahwa untuk mewujudkan fungsi dan tujuan p...
# 1634   a. bahwa untuk kesinambungan kepemimpinan di ...
# 1635   a. bahwa Anggaran Pendapatan dan Belanja Nega...
#
#                                                 heading  \
# 0                                                    []
# 1     ['Pengertian', 'Ruang Lingkup', 'Sistem Akunta...
# 2                                                    []
# 3     ['Tujuan', 'Prinsip', 'Bentuk', 'Ruang Lingkup...
# 4                                                    []
# ...                                                 ...
# 1631                                                 []
# 1632                                                 []
# 1633                                                 []
# 1634                                                 []
# 1635                                                 []
#
#                                         definition_term  token_count
# 0                                                   NaN          258
# 1     ['Kontraktor Kontrak Kerja Sama,', 'Barang yan...          397
# 2     ['Alokasi Dana Bagi Hasil Sumber Daya Alam Keh...           89
# 3     ['Badan Usaha Penyedia Jasa Penyiapan Proyek K...          500
# 4                                                   NaN          341
# ...                                                 ...          ...
# 1631  ['Keimigrasian', 'Wilayah Negara Republik Indo...          219
# 1632  ['Usaha Kecil', 'Usaha Menengah dan Usaha Besa...          289
# 1633  ['Badan hukum pendidikan', 'Badan Hukum Pendid...          368
# 1634                                                NaN          283
# 1635                                                NaN          529
#
# [1636 rows x 9 columns]

# %%
# filter rows with token >= 202 and <= 420
#docs_df = docs_df[(docs_df["token_count"] >= 202) & (docs_df["token_count"] <= 420)]
#docs_df

# %%
#docs_df = docs_df[:100]

# %%
# apply api_call function to each row in docs_df
docs_df["generated_topics"] = docs_df.apply(lambda x: api_call(model, generation_prompt.format(doc_title=x["judul"], doc_consideration=x["konsideran"]), 500, 0.5, 0), axis=1)

# %%
docs_df
# Out:
#                  nama_file      nomor_peraturan  \
# 0     01~pmk.010~2011.json  PMK 01/PMK.010/2011
# 1      02~pmk.05~2011.json   PMK 02/PMK.05/2011
# 2      02~pmk.07~2012.json   PMK 02/PMK.07/2012
# 3     03~pmk.011~2012.json  PMK 03/PMK.011/2012
# 4      04~pmk.02~2014.json   PMK 04/PMK.02/2014
# ...                    ...                  ...
# 1631  uu-9-tahun-1992.json      UU 9 TAHUN 1992
# 1632  uu-9-tahun-1995.json      UU 9 TAHUN 1995
# 1633  uu-9-tahun-2009.json      UU 9 TAHUN 2009
# 1634  uu-9-tahun-2015.json      UU 9 TAHUN 2015
# 1635   uu-9tahun-2005.json      UU 9 TAHUN 2005
#
#                                                   judul  tahun  nomor  \
# 0     Perubahan atas Peraturan Menteri Keuangan Nomo...   2011      1
# 1     Pedoman Akuntansi Dan Pelaporan Aset Berupa Ba...   2011      2
# 2     Perkiraan Alokasi Dana Bagi Hasil Sumber Daya ...   2012      2
# 3     Tata Cara Pengelolaan Dan Pertanggungjawaban F...   2012      3
# 4     Perubahan Kedua atas Peraturan Menteri Keuanga...   2014      4
# ...                                                 ...    ...    ...
# 1631                                       Keimigrasian   1992      9
# 1632                                        Usaha Kecil   1995      9
# 1633                             Badan Hukum Pendidikan   2009      9
# 1634  Perubahan Kedua atas Undang-Undang Nomor 23 Ta...   2015      9
# 1635  Perubahan Kedua atas Undang-Undang Nomor 36 Ta...   2005      9
#
#                                              konsideran  \
# 0      a. bahwa dalam rangka memperoleh perhitungan ...
# 1      a. bahwa berdasarkan Peraturan Menteri Keuang...
# 2      bahwa untuk melaksanakan ketentuan Pasal 27 a...
# 3      a. bahwa dalam rangka mendukung usaha pemanfa...
# 4      a. bahwa dalam rangka mendukung agar kondisi ...
# ...                                                 ...
# 1631   a. bahwa pengaturan keimigrasian yang meliput...
# 1632   a. bahwa negara Republik Indonesia yang berda...
# 1633   a. bahwa untuk mewujudkan fungsi dan tujuan p...
# 1634   a. bahwa untuk kesinambungan kepemimpinan di ...
# 1635   a. bahwa Anggaran Pendapatan dan Belanja Nega...
#
#                                                 heading  \
# 0                                                    []
# 1     ['Pengertian', 'Ruang Lingkup', 'Sistem Akunta...
# 2                                                    []
# 3     ['Tujuan', 'Prinsip', 'Bentuk', 'Ruang Lingkup...
# 4                                                    []
# ...                                                 ...
# 1631                                                 []
# 1632                                                 []
# 1633                                                 []
# 1634                                                 []
# 1635                                                 []
#
#                                         definition_term  token_count  \
# 0                                                   NaN          258
# 1     ['Kontraktor Kontrak Kerja Sama,', 'Barang yan...          397
# 2     ['Alokasi Dana Bagi Hasil Sumber Daya Alam Keh...           89
# 3     ['Badan Usaha Penyedia Jasa Penyiapan Proyek K...          500
# 4                                                   NaN          341
# ...                                                 ...          ...
# 1631  ['Keimigrasian', 'Wilayah Negara Republik Indo...          219
# 1632  ['Usaha Kecil', 'Usaha Menengah dan Usaha Besa...          289
# 1633  ['Badan hukum pendidikan', 'Badan Hukum Pendid...          368
# 1634                                                NaN          283
# 1635                                                NaN          529
#
#                                        generated_topics
# 0     Format laporan; Tarif premi; Pendapatan; Profi...
# 1     Pedoman Akuntansi; Pelaporan Aset; Barang Mili...
# 2     Peraturan; Alokasi Dana; Bagi Hasil; Sumber Da...
# 3     Pemanfaatan panas bumi; Risiko usaha panas bum...
# 4     Perimbangan kekayaan dan kewajiban; Badan peny...
# ...                                                 ...
# 1631  Pengaturan keimigrasian; Lalu lintas orang; Ke...
# 1632  Pembangunan Nasional; Masyarakat Adil dan Makm...
# 1633  Otonomi pendidikan; Pengelolaan pendidikan for...
# 1634  Peralihan kepemimpinan; Mekanisme demokratis; ...
# 1635  Pelaksanaan APBN; Pembahasan Rancangan Undang-...
#
# [1636 rows x 10 columns]

# %%
# save generated topics to csv
docs_df.to_csv("../../data/law_analyzer_new99_generated_topics_all.csv", index=False)
